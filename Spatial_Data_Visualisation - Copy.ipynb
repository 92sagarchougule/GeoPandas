# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import geopandas as fpd
import geopandas

# %%
df = pd.read_csv('OutBreak.csv')

# %%
df.head(2)
# Out:
#          Lat       Long  Sl._No.  Taluk   Village/urban          Outbreak  \
# 0  15.705917  75.655224        1    Ron  Arahunsi Grama  Gasteroenteritis
# 1  15.296969  75.493228        2  Gadag      Chinchalli            Dengue
#
#    Population  people_suspected        Date  year
# 0       23453                 9   17.3.2013  2013
# 1        3245                 5  11.11.2013  2013

# %%
gdf = geopandas.GeoDataFrame(
    df, geometry=geopandas.points_from_xy(df.Long, df.Lat))

# %%
print(gdf.head())
# Out:
#          Lat       Long  Sl._No.     Taluk   Village/urban          Outbreak  \
# 0  15.705917  75.655224        1       Ron  Arahunsi Grama  Gasteroenteritis
# 1  15.296969  75.493228        2     Gadag      Chinchalli            Dengue
# 2  15.383358  75.820894        3  Mundargi          Jantli       Chikungunya
# 3  15.659548  75.860875        4       Ron     Nidagundi    Gasteroenteritis
# 4  15.294716  75.720434        5  Mundargi            Doni    food poisoning
#
#    Population  people_suspected        Date  year                   geometry
# 0       23453                 9   17.3.2013  2013  POINT (75.65522 15.70592)
# 1        3245                 5  11.11.2013  2013  POINT (75.49323 15.29697)
# 2        3477                14  06.11.2013  2013  POINT (75.82089 15.38336)
# 3         564                12  02.02.2013  2013  POINT (75.86087 15.65955)
# 4        4568               110   10.1.2014  2014  POINT (75.72043 15.29472)

# %%
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf.columns
# Out:
# Index(['Lat', 'Long', 'Sl._No.', 'Taluk', 'Village/urban', 'Outbreak',
#        'Population', 'people_suspected', 'Date', 'year', 'geometry'],
#       dtype='object')

# %%
gdf.plot(column='Outbreak', marker='.', markersize = 140,legend=True,
             legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5)}, figsize = (8,18))
# Out:
# <AxesSubplot:>

# %%
import branca as bc
import folium
import matplotlib.pyplot as plt
from mapclassify import classify

# %%
vf = fpd.read_file(r'C:\Users\Lenovo\Documents\GeoPandas\Nagveni_Mam\Villages.shp')
outbrk = fpd.read_file(r'C:\Users\Lenovo\Documents\GeoPandas\Nagveni_Mam\Outbreaks.shp')

# %%
#gdfc = geopandas.GeoDataFrame(vf, crs=4326)
#outfc = geopandas.GeoDataFrame(outbrk, crs=4326)

# %%
#vf.plot()

# %%
ax = vf.plot(color='gray',edgecolor='white', alpha=0.5, figsize = (10,10),cmap='tab20',legend=True,
             legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5)})
outbrk.plot(ax=ax,color='red', marker='o',figsize = (10,10),markersize=outbrk['Suspect_Po']*4)
# Out:
# <AxesSubplot:>

# %%
outbrk.columns
# Out:
# Index(['Sl._No.', 'Lat', 'Long', 'Taluk', 'Village/ur', 'Outbreak',
#        'Village_Po', 'Suspect_Po', 'Start_Date', 'Year', 'geometry'],
#       dtype='object')

# %%
outbrk.crs
# Out:
# <Geographic 2D CRS: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84" ...>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (Degree)
# - lat[north]: Latitude (Degree)
# Area of Use:
# - undefined
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdfc.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich
