# %%
import geopandas as pgd
import matplotlib 
# %matplotlib inline

# %%
luPoly = pgd.read_file(r'C:\Users\Lenovo\Documents\GeoPandas\Shapefiles\Land Use Pattern.shp')

# %%
luPoly.head()
# Out:
#    LUP    Area Field-No       LUP-Name  \
# 0   18  0.2342      F-1          Roads
# 1    3  0.0083      F-2  Field Borders
# 2    3  0.0192      F-3  Field Borders
# 3    3  0.0114      F-4  Field Borders
# 4    1  0.1650      F-5    Agriculture
#
#                                             geometry
# 0  POLYGON ((75.04240 17.02634, 75.04244 17.02631...
# 1  POLYGON ((75.02106 17.06095, 75.02155 17.06097...
# 2  POLYGON ((75.02105 17.06131, 75.02154 17.06130...
# 3  POLYGON ((75.01650 17.05566, 75.01597 17.05550...
# 4  POLYGON ((75.01597 17.05550, 75.01650 17.05566...

# %%
luPoly.columns
# Out:
# Index(['LUP', 'Area', 'Field-No', 'LUP-Name', 'geometry'], dtype='object')

# %%
luPoly.tail()
# Out:
#        LUP    Area Field-No      LUP-Name  \
# 11757   10  0.0411  F-10748       Streams
# 11758   10  0.6591   F-9093       Streams
# 11759   10  0.1752  F-10259       Streams
# 11760    6  0.4467   F-3769  Horticulture
# 11761    4  0.2341   F-7050     Open Land
#
#                                                 geometry
# 11757  POLYGON ((75.02455 17.03430, 75.02449 17.03432...
# 11758  POLYGON ((75.03152 17.02927, 75.03158 17.02931...
# 11759  POLYGON ((75.02184 17.02804, 75.02170 17.02811...
# 11760  POLYGON ((75.03471 17.06441, 75.03471 17.06440...
# 11761  POLYGON ((75.02445 17.03434, 75.02444 17.03429...

# %%
luPoly.plot()
# Out:
# <AxesSubplot:>

# %%
for item in luPoly.columns[:-2]:
    uniquelist = luPoly[item].unique()
    if(uniquelist.flatten().shape[0] < 10):
        print("Unique name {}".format(item))
        print("Unique name {}".format(luPoly[item].unique()))
        print("---------------")

# %%
import matplotlib  as plt

# %%
luPoly.plot(column = 'LUP-Name')
#luPoly.legend()
# Out:
# <AxesSubplot:>

# %%
luPoly.total_bounds
# Out:
# array([75.00079733, 17.02309745, 75.05115528, 17.08828243])

# %%
luPoly.describe
# Out:
# <bound method NDFrame.describe of        LUP    Area Field-No       LUP-Name  \
# 0       18  0.2342      F-1          Roads
# 1        3  0.0083      F-2  Field Borders
# 2        3  0.0192      F-3  Field Borders
# 3        3  0.0114      F-4  Field Borders
# 4        1  0.1650      F-5    Agriculture
# ...    ...     ...      ...            ...
# 11757   10  0.0411  F-10748        Streams
# 11758   10  0.6591   F-9093        Streams
# 11759   10  0.1752  F-10259        Streams
# 11760    6  0.4467   F-3769   Horticulture
# 11761    4  0.2341   F-7050      Open Land
#
#                                                 geometry
# 0      POLYGON ((75.04240 17.02634, 75.04244 17.02631...
# 1      POLYGON ((75.02106 17.06095, 75.02155 17.06097...
# 2      POLYGON ((75.02105 17.06131, 75.02154 17.06130...
# 3      POLYGON ((75.01650 17.05566, 75.01597 17.05550...
# 4      POLYGON ((75.01597 17.05550, 75.01650 17.05566...
# ...                                                  ...
# ...

# %%
luPoly.geometry
# Out:
# 0        POLYGON ((75.04240 17.02634, 75.04244 17.02631...
# 1        POLYGON ((75.02106 17.06095, 75.02155 17.06097...
# 2        POLYGON ((75.02105 17.06131, 75.02154 17.06130...
# 3        POLYGON ((75.01650 17.05566, 75.01597 17.05550...
# 4        POLYGON ((75.01597 17.05550, 75.01650 17.05566...
#                                ...
# 11757    POLYGON ((75.02455 17.03430, 75.02449 17.03432...
# 11758    POLYGON ((75.03152 17.02927, 75.03158 17.02931...
# 11759    POLYGON ((75.02184 17.02804, 75.02170 17.02811...
# 11760    POLYGON ((75.03471 17.06441, 75.03471 17.06440...
# 11761    POLYGON ((75.02445 17.03434, 75.02444 17.03429...
# Name: geometry, Length: 11762, dtype: geometry

# %%
#Move for Line

# %%
strm = pgd.read_file(r'C:\Users\Lenovo\Documents\GeoPandas\Shapefiles\Roads.shp')

# %%
strm.plot()
# Out:
# <AxesSubplot:>

# %%
strm.columns
# Out:
# Index(['id', 'RoadName', 'RoadType', 'length', 'geometry'], dtype='object')

# %%
strm.type
# Out:
# 0      LineString
# 1      LineString
# 2      LineString
# 3      LineString
# 4      LineString
#           ...
# 138    LineString
# 139    LineString
# 140    LineString
# 141    LineString
# 142    LineString
# Length: 143, dtype: object

# %%
strm['RoadName'].value_counts()
# Out:
# Basapachiwadi Road    8
# Hivre Road            7
# Dhaphlapur Road       3
# Dhalgaon Road         3
# Baj Road              3
# Name: RoadName, dtype: int64

# %%
strm.head()
# Out:
#      id RoadName  RoadType  length  \
# 0  None     None      Path  0.6526
# 1  None     None      Path  0.0678
# 2  None     None      Path  0.1331
# 3  None     None      Path  0.0525
# 4  None     None  Tar Road  5.2706
#
#                                             geometry
# 0  LINESTRING (75.01241 17.04418, 75.01237 17.044...
# 1  LINESTRING (75.02046 17.06367, 75.02033 17.063...
# 2  LINESTRING (75.02438 17.04409, 75.02433 17.044...
# 3  LINESTRING (75.02392 17.04369, 75.02386 17.04415)
# 4  LINESTRING (75.02442 17.04404, 75.02453 17.04413)

# %%
strm[strm['RoadName'] == 'Dhaphlapur Road'].plot()
strm[strm['RoadName'] == 'Hivre Road'].plot()
# Out:
# <AxesSubplot:>

# %%
strm.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
l = []
lt = strm.length
l.append(lt)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_5984/1533892706.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'length' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   lt = strm.length

# %%
l
# Out:
# [0      5.862506e-03
#  1      6.091167e-04
#  2      1.195698e-03
#  3      4.695570e-04
#  4      1.460896e-04
#             ...
#  138    4.818104e-04
#  139    4.783488e-07
#  140    1.301713e-03
#  141    7.731642e-03
#  142    3.918112e-03
#  Length: 143, dtype: float64]
